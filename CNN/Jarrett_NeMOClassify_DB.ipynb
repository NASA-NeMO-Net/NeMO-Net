# %%
import sys
sys.path.append("./utils/") # Adds higher directory to python modules path.
import random
import numpy as np
import glob, os
import json
import pandas as pd
import cv2
from NeMO_3dApputils import Coral3DData, CoralImageList

from matplotlib import colors
import matplotlib.patches as mpatches
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot as plt
# %matplotlib notebook
# Out:
# Using TensorFlow backend.

# %%
classify_masterfile = "/home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_May/NeMO-MayCSVs/ClassificationAttempts_May_Master.csv"
img_path = "/home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_May"
NeMO_Data = Coral3DData(classify_masterfile, img_path = img_path, meshType = ["3D"])
NeMO_Data.load_satellite_transect_data()
print(NeMO_Data.unique_transects)
# Out:
# Total number of lines in /home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_May/NeMO-MayCSVs/ClassificationAttempts_May_Master.csv is: 54404
# Will attempt to load only ['3D'] data
# Will attempt to load all relevant files...
# ['guam transect 2 1_4' 'guam transect 2019_05_13_01 4_3'
#  'guam transect 2 4_3' 'guam transect 2 2_5'
#  'puertoRico transect 2019_03_12_01 2_2' 'guam transect 2 3_3'
#  'guam transect 2019_05_09_02 3_2' 'guam transect 2019_05_09_02 3_5'
#  'PR_Siderastreidae' 'guam transect 2019_05_09_04 1_2'
#  'guam transect 2019_05_09_02 1_2' 'guam transect 1 3_1'
#  'guam transect 1 4_2' 'puertoRico transect 2019_03_12_01 3_4'
#  'KAH_SIO_S05_4_2' 'KAH_SIO_S05_7_6'
#  'puertoRico transect 2019_03_14_01 5_4' 'guam transect 2019_05_13_01 1_4'
#  'guam transect 2019_05_09_01 5_2' 'puertoRico transect 2019_03_14_03 4_4'
#  'guam transect 2019_05_09_04 1_4' 'guam transect 2019_05_09_01 4_2'
#  'guam transect 1 5_4' 'guam transect 2019_05_09_04 2_4'
#  'guam transect 2019_05_13_01 3_5' 'samoa_2013_cropped_1_3'
#  'samoa_2013_cropped_3_1' 'guam transect 2 2_1' 'samoa_2013_cropped_6_1'
#  'KAH_SIO_S05_1_5' 'guam transect 1 2_2' 'samoa_2013_cropped_6_3'
#  'guam transect 2019_05_09_01 2_3' 'puertoRico transect 2019_03_14_01 1_1'
#  'samoa_2013_cropped_6_2' 'guam transect 2 5_4'
#  'guam transect 2019_05_09_01 4_3' 'guam transect 2019_05_13_01 3_3'
#  'guam transect 1 3_2' 'guam transect 2019_05_09_04 2_2'
#  'guam transect 2019_05_09_03 3_4' 'guam transect 2019_05_13_01 2_1'
#  'guam transect 2019_05_09_01 2_1' 'guam transect 2019_05_13_01 1_3'
#  'guam transect 2019_05_09_01 4_4' 'guam transect 2 4_5'
#  'guam transect 2 3_2' 'guam transect 2019_05_09_04 3_4'
#  'guam transect 2019_05_13_01 3_1' 'puertoRico transect 2019_03_12_01 4_4'
#  'guam transect 1 3_4' 'KAH_SIO_S05_6_8' 'guam transect 2019_05_13_01 2_3'
#  'guam transect 1 4_4' 'guam transect 1 2_4'
#  'guam transect 2019_05_09_03 2_2' 'KAH_SIO_S05_3_7'
#  'guam transect 2019_05_09_02 5_3' 'KAH_SIO_S05_3_1'
#  'guam transect 2019_05_09_03 4_5' 'guam transect 2019_05_09_01 1_2'
#  'guam transect 2019_05_09_04 4_4' 'guam transect 2019_05_09_04 2_1'
#  'samoa_2013_cropped_5_4' 'KAH_SIO_S05_2_5'
#  'puertoRico transect 2019_03_14_03 2_4' 'guam transect 2019_05_09_02 2_3'
#  'guam transect 2019_05_09_01 5_4' 'guam transect 2019_05_09_03 2_1'
#  'samoa_2013_cropped_4_4' 'guam transect 1 4_1' 'samoa_2013_cropped_1_1'
#  'samoa_2013_cropped_5_1' 'guam transect 2 2_4' 'samoa_2013_cropped_1_4'
#  'KAH_SIO_S05_3_2' 'KAH_SIO_S05_4_1' 'samoa_2013_cropped_3_3'
#  'puertoRico transect 2019_03_14_01 3_2' 'samoa_2013_cropped_2_2'
#  'guam transect 2019_05_09_01 3_2' 'guam transect 2019_05_13_01 4_4'
#  'puertoRico transect 2019_03_14_02 1_1'
#  'puertoRico transect 2019_03_14_02 1_2' 'samoa_2013_cropped_5_2'
#  'guam transect 1 3_3' 'guam transect 2 3_1'
#  'guam transect 2019_05_09_03 1_4' 'guam transect 1 4_3'
#  'guam transect 2019_05_09_02 3_4' 'KAH_SIO_S05_4_3'
#  'puertoRico transect 2019_03_14_03 2_5' 'KAH_SIO_S05_4_8'
#  'puertoRico transect 2019_03_12_02 2_4' 'guam transect 2 2_3'
#  'samoa_2013_cropped_3_4' 'guam transect 2 4_1'
#  'puertoRico transect 2019_03_14_01 3_4' 'KAH_SIO_S05_7_7'
#  'guam transect 2019_05_09_02 3_3' 'puertoRico transect 2019_03_14_03 3_4'
#  'guam transect 2019_05_09_04 2_3' 'guam transect 2019_05_09_01 5_1'
#  'guam transect 2 2_2' 'samoa_2013_cropped_4_1'
#  'guam transect 2019_05_09_01 4_5' 'guam transect 2019_05_09_04 4_3'
#  'samoa_2013_cropped_2_3' 'samoa_2013_cropped_1_2' 'KAH_SIO_S05_2_3'
#  'puertoRico transect 2019_03_14_02 1_3' 'guam transect 1 4_5'
#  'KAH_SIO_S05_2_4' 'guam transect 2 4_2' 'guam transect 2019_05_09_01 2_5'
#  'puertoRico transect 2019_03_12_01 1_2' 'guam transect 2019_05_09_04 3_3'
#  'puertoRico transect 2019_03_12_02 4_4' 'guam transect 2019_05_09_01 4_1'
#  'guam transect 2019_05_09_01 3_4' 'KAH_SIO_S05_7_5'
#  'guam transect 2019_05_09_01 3_5' 'guam transect 2019_05_09_04 3_5'
#  'guam transect 2019_05_09_02 4_2' 'guam transect 2 5_3'
#  'samoa_2013_cropped_6_4' 'KAH_SIO_S05_5_6'
#  'guam transect 2019_05_09_01 3_1' 'KAH_SIO_S05_5_7'
#  'guam transect 2019_05_09_04 4_5' 'guam transect 2019_05_13_01 5_3'
#  'guam transect 2019_05_13_01 2_4' 'puertoRico transect 2019_03_14_01 5_3'
#  'guam transect 2019_05_09_04 2_5' 'samoa_2013_cropped_2_4'
#  'guam transect 2019_05_13_01 3_2' 'guam transect 2019_05_09_01 5_3'
#  'guam transect 2 1_5' 'guam transect 1 2_3'
#  'guam transect 2019_05_09_02 4_3' 'KAH_SIO_S05_4_7'
#  'puertoRico transect 2019_03_14_01 3_3' 'guam transect 2 4_4'
#  'samoa_2013_cropped_5_3' 'KAH_SIO_S05_2_2'
#  'guam transect 2019_05_09_01 2_2' 'guam transect 1 1_3'
#  'samoa_2013_cropped_4_3' 'samoa_2013_cropped_2_1' 'KAH_SIO_S05_3_4'
#  'guam transect 2019_05_13_01 4_2' 'KAH_SIO_S05_2_6'
#  'puertoRico transect 2019_03_14_01 4_4' 'samoa_2013_cropped_4_2'
#  'guam transect 1 2_1' 'guam transect 2019_05_09_04 1_3'
#  'guam transect 2 1_2' 'puertoRico transect 2019_03_14_01 2_4'
#  'guam transect 2019_05_13_01 1_5' 'KAH_SIO_S05_3_5'
#  'guam transect 2019_05_13_01 1_2' 'puertoRico transect 2019_03_12_01 2_1'
#  'KAH_SIO_S05_5_2' 'guam transect 2019_05_09_03 2_3' 'guam transect 1 5_5'
#  'puertoRico transect 2019_03_12_01 1_3' 'guam transect 2019_05_09_01 2_4'
#  'samoa_2013_cropped_3_2' 'guam transect 2019_05_13_01 3_4'
#  'KAH_SIO_S05_7_4' 'guam transect 2019_05_09_03 1_3' 'guam transect 1 5_3'
#  'puertoRico transect 2019_03_14_03 1_2'
#  'puertoRico transect 2019_03_14_01 4_3' 'guam transect 2019_05_09_01 1_3'
#  'guam transect 1 1_2' 'guam transect 2019_05_13_01 4_5'
#  'guam transect 2 3_4' 'guam transect 2019_05_09_02 2_4'
#  'guam transect 2019_05_13_01 4_1' 'puertoRico transect 2019_03_12_02 2_2'
#  'guam transect 2 1_3' 'guam transect 2019_05_09_02 1_3'
#  'guam transect 2019_05_09_03 2_4' 'KAH_SIO_S05_3_6' 'KAH_SIO_S05_4_6'
#  'guam transect 2019_05_09_02 2_2' 'guam transect 2 3_5'
#  'puertoRico transect 2019_03_14_03 3_5' 'guam transect 2019_05_09_01 1_1'
#  'guam transect 2019_05_13_01 5_2' 'guam transect 2019_05_09_01 3_3'
#  'guam transect 2019_05_09_03 3_5' 'KAH_SIO_S05_5_1'
#  'guam transect 2019_05_09_03 2_5' 'guam transect 2019_05_13_01 2_5'
#  'guam transect 2 5_2' 'guam transect 2019_05_13_01 2_2']

# %%
sub_userdf, user_pd_vals = NeMO_Data.filter_by_user(transect_num=20, user_rating=0.5) # only find users with more than 20 transect classifications
# sub_userdf = NeMO_Data.filter_by_rating(input_pd = user_pd, rating_range=[1,2], include_nan = False)

CIL = CoralImageList()
for i in range(len(sub_userdf)):
    classification_fileID = sub_userdf.iloc[i]['Classification_fileID']
    transect_fileID = sub_userdf.iloc[i]['Transect_fileID']
    try:
        coralimage = NeMO_Data.load_classification(classification_fileID = classification_fileID)
        CIL.append(coralimage)
        print(str(i+1) + "/" + str(len(sub_userdf)) + " " + classification_fileID + " loaded, corresponding to " + transect_fileID, end='\r')
    except FileNotFoundError:
        print(str(i+1) + "/" + str(len(sub_userdf)) + " " + "Skipping " + classification_fileID + ", corresponding to " + transect_fileID + "!", end='\r')

CIL.output_training(directory = "/home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_Training", add_to_dir = False)
# Out:
# [ 225  249  499  536  640  675  756  856  928 1087 1484 1504 1576 1591
#  1599 1710 1963 2092 2132 2525 2749 2914 2975 3068 3097 3133 3237 3572
#  3712 4257 4281 4295 4599 4884 5062 5247 5302 5458 5479 5565 5585 5836
#  5907 6017 6154 6242 6526 6561 6605 6657 6962 7379 7744 8065 8242 8251
#  8683]
# Transect File for samoa_2013_cropped_6_1 not found! corresponding to guam transect 2019_05_13_01 4_301 4_4
# Transect File for samoa_2013_cropped_6_2 not found! corresponding to guam transect 2019_05_09_01 1_2
# Transect File for samoa_2013_cropped_1_1 not found! corresponding to puertoRico transect 2019_03_12_01 2_2
# Transect File for samoa_2013_cropped_3_3 not found! corresponding to guam transect 2019_05_13_01 3_103 2_5
# Transect File for samoa_2013_cropped_3_4 not found!F, corresponding to samoa_2013_cropped_3_3!
# Transect File for samoa_2013_cropped_2_3 not found! corresponding to guam transect 2019_05_13_01 4_3
# Transect File for samoa_2013_cropped_1_2 not found!1, corresponding to samoa_2013_cropped_2_3!
# Transect File for samoa_2013_cropped_6_1 not found! corresponding to guam transect 2019_05_09_01 4_1
# Classification file not found at /home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_May/projections/guam transect 1 1_3/proj_EBF85A40-D155-41F3-8AE8-B7ACCC195DFA.png!
# Transect File for samoa_2013_cropped_2_1 not found! corresponding to puertoRico transect 2019_03_14_03 1_2
# Transect File for samoa_2013_cropped_2_3 not found! corresponding to KAH_SIO_S05_2_4opped_2_1!
# Transect File for samoa_2013_cropped_1_3 not found! corresponding to KAH_SIO_S05_6_8sect 2019_03_14_01 4_3
# Transect File for samoa_2013_cropped_5_2 not found! corresponding to KAH_SIO_S05_7_5 2_3 2019_03_14_03 3_4
# Transect File for samoa_2013_cropped_1_2 not found!, corresponding to KAH_SIO_S05_3_4 2_25_09_02 1_3
# Transect File for samoa_2013_cropped_4_1 not found!, corresponding to guam transect 2019_05_09_04 4_503 3_5
# Transect File for samoa_2013_cropped_5_1 not found!, corresponding to guam transect 2019_05_09_02 1_301 3_4
# Transect File for samoa_2013_cropped_6_3 not found!, corresponding to puertoRico transect 2019_03_14_01 2_4
# Transect File for samoa_2013_cropped_1_3 not found!, corresponding to guam transect 2019_05_09_04 2_401 5_3
# Classification file not found at /home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_May/projections/guam transect 1 4_3/proj_26771396-3C71-484D-A689-D2CCB68CB70E.png!
# Transect File for samoa_2013_cropped_3_3 not found!, corresponding to guam transect 1 3_1 2019_03_14_02 1_2
# Classification file not found at /home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_May/projections/guam transect 2 4_3/proj_8980442C-07C5-45CE-A4BD-9897B3BCFA61.png!
# Transect File for samoa_2013_cropped_5_1 not found!, corresponding to guam transect 2019_05_09_01 3_3
# Transect File for samoa_2013_cropped_1_1 not found!, corresponding to guam transect 2019_05_13_01 3_403 3_4
# Transect File for samoa_2013_cropped_3_4 not found!, corresponding to guam transect 1 3_105_09_01 4_2
# Transect File for samoa_2013_cropped_1_4 not found!, corresponding to guam transect 2019_05_13_01 4_2
# Transect File for samoa_2013_cropped_4_1 not found!, corresponding to guam transect 2 5_405_09_04 2_1
# Transect File for samoa_2013_cropped_6_2 not found!, corresponding to guam transect 2019_05_09_02 3_5
# Transect File for samoa_2013_cropped_5_4 not found!, corresponding to puertoRico transect 2019_03_14_01 4_3
# Transect File for samoa_2013_cropped_4_1 not found!, corresponding to PR_Siderastreidaect 2019_03_14_03 3_5
# Transect File for samoa_2013_cropped_2_1 not found!94, corresponding to samoa_2013_cropped_4_1!
# Transect File for samoa_2013_cropped_4_1 not found!, corresponding to guam transect 1 2_305_09_01 5_1
# Transect File for samoa_2013_cropped_3_2 not found!, corresponding to puertoRico transect 2019_03_12_01 2_2
# Classification file not found at /home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_May/projections/guam transect 1 3_4/proj_1951FFB3-7406-497B-ADBA-E4D1F729439D.png!
# Transect File for samoa_2013_cropped_5_1 not found!, corresponding to guam transect 2 1_405_09_01 1_301 3_2
# Transect File for samoa_2013_cropped_6_4 not found!, corresponding to guam transect 2 2_5 2019_03_14_01 5_4
# Transect File for samoa_2013_cropped_3_1 not found!, corresponding to guam transect 2 4_305_09_02 3_202 2_2
# Transect File for samoa_2013_cropped_1_3 not found!A8, corresponding to samoa_2013_cropped_3_1!
# Transect File for samoa_2013_cropped_3_3 not found!7A, corresponding to samoa_2013_cropped_1_3!
# Transect File for samoa_2013_cropped_5_3 not found!05, corresponding to samoa_2013_cropped_3_3!
# Transect File for samoa_2013_cropped_6_4 not found!, corresponding to guam transect 2019_05_13_01 4_201 5_3
# Transect File for samoa_2013_cropped_5_2 not found!, corresponding to KAH_SIO_S05_3_1opped_6_4!
# Classification file not found at /home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_May/projections/guam transect 2 3_3/proj_36D06B0F-F769-4823-899C-BC09863EF011.png!
# Transect File for samoa_2013_cropped_4_3 not found!, corresponding to guam transect 2 3_305_09_02 2_401 3_3
# Transect File for samoa_2013_cropped_5_4 not found!, corresponding to KAH_SIO_S05_7_6019_05_13_01 2_301 5_3
# Transect File for samoa_2013_cropped_3_3 not found!, corresponding to puertoRico transect 2019_03_12_02 2_4
# Transect File for samoa_2013_cropped_1_1 not found!, corresponding to PR_Siderastreidae_305_09_03 4_5
# Transect File for samoa_2013_cropped_3_1 not found!, corresponding to guam transect 2 3_5 2019_03_12_01 2_2
# Transect File for samoa_2013_cropped_3_3 not found!, corresponding to puertoRico transect 2019_03_14_03 3_4
# Classification file not found at /home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_May/projections/guam transect 2019_05_09_01 5_4/proj_A197CE15-AAA7-4372-B789-9F9A51994F59.png!
# Transect File for samoa_2013_cropped_4_3 not found!, corresponding to KAH_SIO_S05_7_4019_05_09_04 3_3_4!
# Transect File for samoa_2013_cropped_4_4 not found!, corresponding to puertoRico transect 2019_03_12_01 2_1
# Transect File for samoa_2013_cropped_6_2 not found!2F, corresponding to samoa_2013_cropped_4_4!
# Transect File for samoa_2013_cropped_4_4 not found!, corresponding to puertoRico transect 2019_03_14_02 1_3
# Transect File for samoa_2013_cropped_3_4 not found!, corresponding to guam transect 2019_05_09_04 2_4
# Transect File for samoa_2013_cropped_5_3 not found!3D, corresponding to samoa_2013_cropped_3_4!
# Transect File for samoa_2013_cropped_4_4 not found!95, corresponding to samoa_2013_cropped_5_3!
# Transect File for samoa_2013_cropped_3_2 not found!, corresponding to guam transect 2019_05_13_01 4_3
# Transect File for samoa_2013_cropped_3_2 not found!, corresponding to guam transect 1 3_1d_3_2!
# Transect File for samoa_2013_cropped_6_1 not found!, corresponding to KAH_SIO_S05_4_6019_05_09_01 2_3
# Classification file not found at /home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_May/projections/guam transect 2019_05_09_03 2_5/proj_F3A66A4F-C526-40AE-98A7-F42CE8476259.png!
# Classification file not found at /home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_May/projections/guam transect 2019_05_09_01 2_2/proj_24B15E78-0732-4B52-9EBF-A238C3730EA0.png!
# Transect File for samoa_2013_cropped_1_3 not found!, corresponding to guam transect 2019_05_09_02 2_401 2_2
# Transect File for samoa_2013_cropped_1_2 not found!, corresponding to guam transect 2 4_3d_1_3!
# Transect File for samoa_2013_cropped_3_1 not found!, corresponding to guam transect 1 5_405_09_04 3_301 2_4
# Transect File for samoa_2013_cropped_2_4 not found!, corresponding to guam transect 2019_05_09_03 1_4
# Transect File for samoa_2013_cropped_1_4 not found!, corresponding to guam transect 2 4_1 2019_03_12_01 2_2
# Transect File for samoa_2013_cropped_2_2 not found!, corresponding to guam transect 2019_05_09_01 1_201 2_2
# Transect File for samoa_2013_cropped_2_3 not found!, corresponding to guam transect 1 4_5d_2_2!
# Transect File for samoa_2013_cropped_4_2 not found!19, corresponding to samoa_2013_cropped_2_3!
# Transect File for samoa_2013_cropped_6_3 not found!, corresponding to guam transect 2 3_4 2019_03_12_02 4_4
# Transect File for samoa_2013_cropped_1_4 not found!, corresponding to guam transect 2019_05_09_03 2_501 2_2
# Transect File for samoa_2013_cropped_5_4 not found!, corresponding to KAH_SIO_S05_7_6 3_5d_1_4!
# Transect File for samoa_2013_cropped_6_3 not found!5B, corresponding to samoa_2013_cropped_5_4!
# Classification file not found at /home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_May/projections/guam transect 1 2_4/proj_6E23F42B-792B-4FA7-946C-A50176E503B0.png!
# Classification file not found at /home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_May/projections/guam transect 2019_05_09_04 4_4/proj_65B9683F-E657-4430-8993-1E14D9740F7A.png!
# Transect File for samoa_2013_cropped_2_4 not found!, corresponding to puertoRico transect 2019_03_12_01 1_2
# Classification file not found at /home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_May/projections/guam transect 2019_05_13_01 4_3/proj_56274EE7-2DC1-46FA-B02A-572ADF85A650.png!
# Transect File for samoa_2013_cropped_1_1 not found!, corresponding to guam transect 2019_05_09_03 1_3_3!
# Transect File for samoa_2013_cropped_2_1 not found!, corresponding to puertoRico transect 2019_03_12_01 2_1
# Transect File for samoa_2013_cropped_4_2 not found!, corresponding to guam transect 2019_05_09_01 2_3
# Transect File for samoa_2013_cropped_4_2 not found!, corresponding to guam transect 2019_05_09_01 4_501 1_3
# Transect File for samoa_2013_cropped_2_2 not found!, corresponding to guam transect 2 1_5d_4_2!
# Transect File for samoa_2013_cropped_2_2 not found!, corresponding to KAH_SIO_S05_2_6019_05_09_04 1_301 3_4
# Transect File for samoa_2013_cropped_1_3 not found!, corresponding to guam transect 1 4_5 2019_03_14_02 1_1
# Transect File for samoa_2013_cropped_3_1 not found!, corresponding to guam transect 1 3_305_09_01 5_4
# Transect File for samoa_2013_cropped_1_4 not found!, corresponding to KAH_SIO_S05_3_6019_05_09_02 3_401 5_3
# Transect File for samoa_2013_cropped_5_4 not found!, corresponding to guam transect 2019_05_09_04 1_301 4_4
# Transect File for samoa_2013_cropped_3_4 not found!, corresponding to guam transect 2 5_3d_5_4!
# Transect File for samoa_2013_cropped_6_2 not found!, corresponding to guam transect 2 4_305_09_01 5_202 2_4
# Transect File for samoa_2013_cropped_2_4 not found!, corresponding to puertoRico transect 2019_03_12_01 1_3
# Transect File for samoa_2013_cropped_2_4 not found!, corresponding to guam transect 2019_05_09_04 2_1
# 663/663 DD5C9D5C-9D86-4346-B63D-ECEFE3AA116D loaded, corresponding to guam transect 2019_05_13_01 1_302 2_2
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-4-90ca733e6c6f> in <module>
#      13         print(str(i+1) + "/" + str(len(sub_userdf)) + " " + "Skipping " + classification_fileID + ", corresponding to " + transect_fileID + "!", end='\r')
#      14
# ---> 15 CIL.output_training(directory = "/home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_Training", add_to_dir = False)
#
# ~/Documents/NeMO-Net/NeMO-NET/CNN/utils/NeMO_3dApputils.py in output_training(self, directory, add_to_dir)
#      71                 else:
#      72                         for f in trainfiles:
# ---> 73                                 os.remove(os.path.join(trainpath, f))
#      74                         for f in labelfiles:
#      75                                 os.remove(os.path.join(labelpath, f))
#
# IsADirectoryError: [Errno 21] Is a directory: '/home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_Training/TrainImages/No Data'

# %%
rating_df = NeMO_Data.filter_by_rating(transect_df, rating_range=[1,2], include_nan = False)
img_class_median, img_median_dev = NeMO_Data.median_stack_img(rating_df)

fig = plt.figure(figsize=(8,8))
ax = plt.subplot(2,2,1)
ax.imshow(img_class_median.astype(int), interpolation='nearest', cmap=NeMO_Data.cmap, norm=NeMO_Data.norm)
ax.set_title("Median Classifications")

ax = plt.subplot(2,2,2)
ax.imshow(img_median_dev)
ax.set_title("Deviation from Median")
ax.legend([mpatches.Patch(color=NeMO_Data.cmap(i)) for i in range(len(NeMO_Data.cmap.colors))],
           ['{}'.format(list(NeMO_Data.coralcolors_dict.keys())[i]) for i in range(len(NeMO_Data.coralcolors_dict))],
          loc='upper center', bbox_to_anchor=(0.0,-0.1), ncol=3)

plt.show()
# Out:
# File not found at /home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData/projections/guam transect 2 1_4/proj_5196FA63-C4E7-4481-9C7D-00DFC983F9D3.png!
# <img src="data:image/png;base64,..." width="800">

# %%
user_pd, user_pd_vals = NeMO_Data.filter_by_user(transect_num=15)
unique_users = user_pd.User_ID.unique()

avg_ratings = []
hours_played = []

for usr in unique_users:
    user_df = NeMO_Data.NeMO_df.loc[NeMO_Data.NeMO_df['User_ID'] == usr]
    print(usr, user_df['User_Email'].iloc[0])
    avg_ratings.append(np.mean(user_df.Rating))
    hours_played.append(np.mean(user_df.Hours_Played))

fig = plt.figure(figsize=(5,5)) 
plt.scatter(hours_played, avg_ratings)
plt.grid()
plt.show()
# Out:
# b4991fb6-8216-11ea-965c-02d709759666 nan
# 9a7d2c06-84d0-11ea-965c-02d709759666 rangerkaren@comcast.net
# 8f5c0e1a-83d5-11ea-965c-02d709759666 nan
# c00f4c8b-8143-11ea-965c-02d709759666 thecosmictrickster@outlook.com
# 3b27f082-7b3f-11ea-965c-02d709759666 nan
# 11655b65-8576-11ea-965c-02d709759666 nan
# 4fe0d216-8180-11ea-965c-02d709759666 mageem771@gmail.com
# 9ad95772-8e30-11ea-965c-02d709759666 nan
# 170a6ca8-7a87-11ea-965c-02d709759666 mizuiro22@mail.ru
# ba4b3487-84f6-11ea-965c-02d709759666 mdparnell13@gmail.com
# 574f6ae2-818b-11ea-965c-02d709759666 laneypound@gmail.com
# 065e5c92-7a8c-11ea-965c-02d709759666 nan
# b947503f-87e7-11ea-965c-02d709759666 nan
# 088411ac-7e62-11ea-965c-02d709759666 nan
# 3c9cce8f-7b51-11ea-965c-02d709759666 nan
# 10f8d9a1-7b8c-11ea-965c-02d709759666 nan
# ca3008b8-83c1-11ea-965c-02d709759666 nan
# 26ade08d-84d7-11ea-965c-02d709759666 nan
# 231de9f4-8511-11ea-965c-02d709759666 ericavanname@yahoo.com
# a266e7d9-7ed7-11ea-965c-02d709759666 iris.perfetto@gmail.com
# bcbad0cb-8598-11ea-965c-02d709759666 prettygoodmilkshake@gmail.com
# cbe0d5a4-7b7b-11ea-965c-02d709759666 nan
# d1029e03-7f5b-11ea-965c-02d709759666 dcain1@neo.rr.com
# 2ae4cb12-8686-11ea-965c-02d709759666 nan
# 74bda9ea-7c8f-11ea-965c-02d709759666 lenore01lotor@yahoo.com
# f0dd9427-81c1-11ea-965c-02d709759666 nan
# ca47dd81-81ec-11ea-965c-02d709759666 andrewwilds@yahoo.com
# 191aa0ca-81b1-11ea-965c-02d709759666 jbaylorh@gmail.com
# 8a3c3796-7c3f-11ea-965c-02d709759666 toto_48313@yahoo.fr
# 28f75f4c-8341-11ea-965c-02d709759666 camillepaxton@icloud.com
# 9392d260-80ae-11ea-965c-02d709759666 nan
# 2deec72c-7e77-11ea-965c-02d709759666 nan
# 7608a823-84c6-11ea-965c-02d709759666 nan
# ad1c0764-8269-11ea-965c-02d709759666 rahrendes@hotmail.com
# a53d2ff2-82e6-11ea-965c-02d709759666 nan
# 96dbd628-8801-11ea-965c-02d709759666 kitho73@gmail.com
# e8a9dabc-81f6-11ea-965c-02d709759666 nan
# 3a006d0d-80cf-11ea-965c-02d709759666 nan
# 00437078-7e83-11ea-965c-02d709759666 nan
# 54ee4591-93ad-11ea-965c-02d709759666 nan
# 2e32c0a0-8178-11ea-965c-02d709759666 djkennetha@aol.com
# 422b279b-7bfd-11ea-965c-02d709759666 nan
# 054140e8-7fa3-11ea-965c-02d709759666 done@seaspirts.de
# 04cee059-8121-11ea-965c-02d709759666 kinnakeet57@live.com
# 63316564-83e6-11ea-965c-02d709759666 claire@deentaylor.com
# 4e6fa735-7dc5-11ea-965c-02d709759666 mjgreer@gmail.com
# ceb26469-81df-11ea-965c-02d709759666 eestefandds@hotmail.com
# 775cd450-80ce-11ea-965c-02d709759666 nan
# 090bd8e6-831f-11ea-965c-02d709759666 lbschumacher@gmail.com
# e4c8b722-81bd-11ea-965c-02d709759666 nan
# 03fb82dd-82a2-11ea-965c-02d709759666 nan
# 2f1767b1-6a25-11ea-965c-02d709759666 nan
# e63b2f41-81e4-11ea-965c-02d709759666 nan
# 3d765c15-8a2d-11ea-965c-02d709759666 nan
# b5f4b4dd-87fd-11ea-965c-02d709759666 nan
# 20cfab32-84d2-11ea-965c-02d709759666 nan
# 25dde227-8ae2-11ea-965c-02d709759666 nan
# 60a4a01d-8319-11ea-965c-02d709759666 inthelastmoment@hotmail.com
# 736badf2-8078-11ea-965c-02d709759666 esther.haines@gmail.com
# c51144bd-84ae-11ea-965c-02d709759666 freydajm@mail.com
# 2b21c09d-7adc-11ea-965c-02d709759666 shadiackanthony@gmail.com
# 6ae7a2bb-822e-11ea-965c-02d709759666 a.jna7285@gmail.com
# b5ec5bc8-7f81-11ea-965c-02d709759666 nan
# ca3bb140-7d0f-11ea-965c-02d709759666 nan
# 021acb25-827a-11ea-965c-02d709759666 nan
# ec13ff31-7d19-11ea-965c-02d709759666 nan
# 97133346-6829-11ea-965c-02d709759666 testovvasilij6@gmail.com
# e2fa5a13-7b18-11ea-965c-02d709759666 asia.s.wolf@gmail.com
# 1c98c60e-7f44-11ea-965c-02d709759666 michelle@texashomemaking.com
# 797eb1d3-81bd-11ea-965c-02d709759666 jskeon@gmail.com
# ad0fa82c-84d3-11ea-965c-02d709759666 nan
# 537d1ce1-85be-11ea-965c-02d709759666 nan
# ba6d0929-84cf-11ea-965c-02d709759666 raydriver25@gmail.com
# d9997b2f-81b2-11ea-965c-02d709759666 nan
# 357ecb9a-8349-11ea-965c-02d709759666 nan
# fb67f1a3-9388-11e9-892b-0239699f2190 rechantizer@gmail.com
# 1419855d-82ce-11ea-965c-02d709759666 mai.ragaie@gmail.com
# 4486bc53-93cc-11ea-965c-02d709759666 nan
# 8352935f-8258-11ea-965c-02d709759666 nan
# 4da5c7db-8291-11ea-965c-02d709759666 nan
# 168709ac-7ada-11ea-965c-02d709759666 nan
# 9688bebc-84bf-11ea-965c-02d709759666 nan
# 4341e877-7b87-11ea-965c-02d709759666 nan
# 4f432061-8ee8-11ea-965c-02d709759666 nan
# 0c7f9896-7dbb-11ea-965c-02d709759666 njhelgason@gmail.com
# 43e3c44a-4b55-11e9-892b-0239699f2190 vandenbergh@baeri.org
# 6a5d96f1-82bd-11ea-965c-02d709759666 nan
# 4932cbe5-7bf0-11ea-965c-02d709759666 nan
# b14a29a6-8d59-11ea-965c-02d709759666 nan
# 069429c6-7e03-11ea-965c-02d709759666 lpeers@me.com
# 9ec374f5-8273-11ea-965c-02d709759666 nan
# f0e12bfb-7f46-11ea-965c-02d709759666 nan
# 53a0dab6-7a87-11ea-965c-02d709759666 ahuckenpahler@gmail.com
# 2b67cec7-8e7d-11ea-965c-02d709759666 thomas.oliver@gmail.com
# c38f133d-8576-11ea-965c-02d709759666 nan
# 16455dc8-8036-11ea-965c-02d709759666 nan
# 39612cb4-947e-11ea-965c-02d709759666 nan
# 88884e39-819f-11ea-965c-02d709759666 nan
# 2e1dc611-7de0-11ea-965c-02d709759666 edmondle64@gmail.com
# 21b98e49-7f77-11ea-965c-02d709759666 nan
# 8d741d8b-7e3f-11ea-965c-02d709759666 nan
# <img src="data:image/png;base64,..." width="500">

# %%
usr_id = '054e4b47-92ba-11e9-892b-0239699f2190' # juan
# usr_id = '1d658e07-9228-11e9-892b-0239699f2190' # ved
# usr_id = '9a7d2c06-84d0-11ea-965c-02d709759666' # ranger-karen
# usr_id = 'fb67f1a3-9388-11e9-892b-0239699f2190' # Alan
# usr_id = '2b67cec7-8e7d-11ea-965c-02d709759666' #thomas oliver

sub_userdf = NeMO_Data.NeMO_df.loc[NeMO_Data.NeMO_df['User_ID'] == usr_id]
print("User:", usr_id, " # of Classifications: ", len(sub_userdf))
print("Mean classification rating: ", np.mean(sub_userdf['Rating']))

startpath = "/home/rechant/Documents/NeMO-Net/NeMO-NET/Images/AppData_May"
folders = [f for f in os.listdir(startpath)]

n_rows = 4
fig_count = 1
missing_files = 0
fig = plt.figure(figsize=(8,n_rows*5))

for n in range(n_rows):
    classification_fileID = sub_userdf.iloc[n]['Classification_fileID']
    print(classification_fileID, sub_userdf.iloc[n]['Transect_fileID'])
    CI = NeMO_Data.load_classification(classification_fileID)

    ax = plt.subplot(n_rows,2,fig_count)
    if CI.image.shape[2] == 8:
        CI_RGB = np.rollaxis(np.asarray([CI.image[:,:,4], CI.image[:,:,2], CI.image[:,:,1]], dtype=np.uint8), 0, 3)
    else:
        CI_RGB = CI.image
    ax.imshow(CI_RGB)
    fig_count += 1
    
    ax = plt.subplot(n_rows,2,fig_count)
    if CI.image.shape[2] == 8:
        ax.imshow(CI.classification.astype(int), interpolation='nearest', cmap=NeMO_Data.cmap_sat, norm=NeMO_Data.norm_sat)
    else:
        ax.imshow(CI.classification.astype(int), interpolation='nearest', cmap=NeMO_Data.cmap3D, norm=NeMO_Data.norm3D)
    ax.set_title(CI.transect_name)
    fig_count += 1 
plt.tight_layout()
plt.show()

print("# of missing files:", missing_files)
# Out:
# User: 054e4b47-92ba-11e9-892b-0239699f2190  # of Classifications:  47
# Mean classification rating:  0.9523809523809523
# <img src="data:image/png;base64,..." width="800">
# FAD12BDB-4290-43AE-ACE4-FC25810AE236 guam transect 2019_05_09_02 1_2
# BB7B13EA-7883-4B64-B14D-E84253CEF944 guam transect 1 4_2
# 48C6E8C7-17C9-4A4F-831E-B437637468A0 guam transect 2 4_3
# 1B36F557-0C2B-43C6-BAE0-BA9E73C9C692 guam transect 2019_05_13_01 4_3
# # of missing files: 0

# %%
# Test sliding window on species richness vs evenness

window_size =64

i=10
classification_fileID = sub_userdf.iloc[i]['Classification_fileID']
CI = NeMO_Data.load_classification(classification_fileID)
print(classification_fileID, sub_userdf.iloc[n]['Transect_fileID'])

unq_classes, unq_num = np.unique(CI.classification, return_counts = True)

img_richness = np.zeros((CI.classification.shape[0]-window_size+1, CI.classification.shape[1]-window_size+1))
img_shannon = np.zeros((CI.classification.shape[0]-window_size+1, CI.classification.shape[1]-window_size+1))
img_simpson = np.zeros((CI.classification.shape[0]-window_size+1, CI.classification.shape[1]-window_size+1))
for j in range(CI.classification.shape[0] - window_size + 1):
    for i in range(CI.classification.shape[1] - window_size + 1):
        unq_classes, unq_num = np.unique(CI.classification[j:j+window_size, i:i+window_size], return_counts= True)
        unq_num = unq_num[unq_classes > 2]
        unq_classes = unq_classes[unq_classes > 2]
        img_richness[j,i] = len(unq_num)
        
        if len(unq_num) > 0:
            N = np.sum(unq_num)
            p = 1/N*unq_num
            img_shannon[j,i] = -np.sum(p*np.log(p))
            if N == 1:
                img_simpson[j,i] = 0
            else:
                img_simpson[j,i] = 1 - np.sum((unq_num*(unq_num-1))/(N*(N-1)))
        else:
            img_shannon[j,i] = 0
            img_simpson[j,i] = 0
        

fig = plt.figure(figsize=(8,8))
CI_RGB = CI.image
ax = plt.subplot(3,2,1)
ax.imshow(CI_RGB)

ax = plt.subplot(3,2,2)
ax.imshow(CI.classification.astype(int), interpolation='nearest', cmap=NeMO_Data.cmap3D, norm=NeMO_Data.norm3D)

ax = plt.subplot(3,2,3)
ax.imshow(img_richness, cmap='jet')

ax = plt.subplot(3,2,4)
ax.imshow(img_shannon, cmap='jet', interpolation='nearest')

ax = plt.subplot(3,2,5)
ax.imshow(img_simpson, cmap='jet', interpolation='nearest')
plt.show()
# Out:
# D5438AA8-BFE9-43C5-B8C3-602E172BE557 guam transect 1 2_3
# <img src="data:image/png;base64,..." width="800">

# %%
for i in range(22):
    print(np.uint8(i*255/CI.num_classes))
print(CI.num_classes)
# Out:
# 0
# 11
# 23
# 34
# 46
# 57
# 69
# 81
# 92
# 104
# 115
# 127
# 139
# 150
# 162
# 173
# 185
# 197
# 208
# 220
# 231
# 243
# 22
