# %%
import sys
sys.path.append("./utils/") # Adds higher directory to python modules path.
import random
import numpy as np
import cv2
import glob, os
import loadcoraldata_utils as coralutils

from matplotlib import pyplot as plt
# %matplotlib notebook
# Out:
# c:\users\rechant\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
imgpath = '../Images/BTPB-WV2-2012-15-8Band-mosaic-GeoTiff-Sample-AOI/BTPB-WV2-2012-15-8Band-mosaic-GeoTiff-Sample-AOI.tif'
tfwpath = '../Images/BTPB-WV2-2012-15-8Band-mosaic-GeoTiff-Sample-AOI/BTPB-WV2-2012-15-8Band-mosaic-GeoTiff-Sample-AOI.tfw'
truthpath = '../Images/Cicia_Habitat_classes_raster_KSLOF.tif'
bathypath = '../Images/Cicia_Bathymetry_sn_KSLOF.tif'

Testutils = coralutils.CoralData(imgpath, Truthpath=truthpath, Bathypath=bathypath, load_type="raster", tfwpath=tfwpath)

# %%
print(Testutils.class_weights)
# k = np.min(Testutils.bathyimage)
# test = (Testutils.bathyimage < -100)
# Testutils.bathyimage[test == True] = -1
print(np.min(Testutils.bathyimage))

plt.figure(1)
plt.imshow(Testutils.truthimage)
plt.show()

plt.figure(2)
plt.imshow(Testutils.bathyimage)
plt.show()
# Out:
# {1.0: 88.47653221434234, 2.0: 89.80176088145858, 4.0: 1082.4136794080437, 5.0: 98.60952054961982, 6.0: 721.6183416828545, 7.0: 76.01791089786049, 8.0: 20.334509740652603, 9.0: 1333.676413623695, 10.0: 3559.328794755421, 23.0: 61.24645798940054, 27.0: 1.7345993658941907, 28.0: 5923.750734368443, 29.0: 3.4011561662965453, 30.0: 346.1446489216924, 33.0: 547.9822984802314, 36.0: 99.81578733378824}
# -1.0
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
