# %%
import sys
sys.path.append("./utils/") # Adds higher directory to python modules path.
import random
import numpy as np
import cv2
import yaml
import glob, os
import loadcoraldata_utils as coralutils
import json
import importlib
from NeMO_generator import NeMOImageGenerator, ImageSetLoader

from matplotlib import pyplot as plt
# %matplotlib notebook
# Out:
# c:\users\rechant\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
jsonpath = './utils/CoralClasses.json'
with open(jsonpath) as json_file:
    json_data = json.load(json_file)
consolclass_count = dict((k, 0) for k in json_data["L3_ClassDict"])
    
for mosaic_count in range(1,42):
    print("Mosaic Count: ", mosaic_count)
    
    imgpath = 'F:/Images/processed_Fiji_files/mosaiced_' + str(mosaic_count).zfill(3) + '.TIF'
    # tfwpath = '../Images/BTPB-WV2-2012-15-8Band-mosaic-GeoTiff-Sample-AOI/BTPB-WV2-2012-15-8Band-mosaic-GeoTiff-Sample-AOI.tfw'
    truthpath = 'F:/Images/processed_Fiji_files/truth_classes_wcldMask_' + str(mosaic_count).zfill(3) + '.TIF'
    # bathypath = '../Images/Cicia_Bathymetry_sn_KSLOF.tif'
    output_trainpath = 'F:/Images/Fiji_Training_Patches_256/'
    output_trainrefpath = 'F:/Images/Fiji_TrainingRef_Patches_256/'
    output_trainfilename = 'rastertrain.txt'
    output_validpath = 'F:/Images/Fiji_Valid_Patches_256/'
    output_validrefpath = 'F:/Images/Fiji_ValidRef_Patches_256/'
    output_validfilename = 'rastervalid.txt'

    Fiji = coralutils.CoralData(imgpath, Truthpath=truthpath, truth_key=json_data["Fiji_ClassDict"], load_type="raster")
    Fiji.Consolidate_classes(newclassdict=json_data["L3_ClassDict"], transferdict=json_data["Fiji2L3_Dict"])
    
    anchormean, anchorstd, anchormin, anchormax = Fiji.get_anchors(classdict = json_data["L3_ClassDict"], 
                                               anchorlist = ['Terrestrial Vegetated', 'Deep Ocean Water'])
    mosaic_mean = np.mean(anchormean, axis=0)
    mosaic_std = 3*np.max(anchorstd, axis=0)
#     mosaic_std = np.max(np.asarray([np.abs(mosaic_mean-np.min(anchormin, axis=0)), 
#                                     np.abs(mosaic_mean-np.max(anchormax, axis=0))]), axis=0)
    # anchorstd = np.max(np.asarray([np.abs(anchormean-anchormin), np.abs(anchormean-anchormax)]), axis=0)
    
    print("Outputing Training...")
    Fiji.export_segmentation_map(output_trainpath, output_trainrefpath, 
                                        output_trainfilename, image_size=256, N=50, lastchannelremove=False, 
                                        subdir=True, cont=True, consolidated = True, 
                                        mosaic_mean = mosaic_mean, mosaic_std = mosaic_std)
    print("\n")
    print("Outputing Validation...")
    Fiji.export_segmentation_map(output_validpath, output_validrefpath, 
                                        output_validfilename, image_size=256, N=5, lastchannelremove=False, 
                                        subdir=True, cont=True, consolidated = True,
                                        mosaic_mean = mosaic_mean, mosaic_std = mosaic_std)
    
    for k in Fiji.consolidated_class_dict:
        consolclass_count[k] = consolclass_count[k] + Fiji.consolclass_count[k]
        
total_pixels = np.sum([consolclass_count[k] for k in Fiji.consolidated_class_dict])
consolclass_weights = dict((k, total_pixels/consolclass_count[k]) for k in Fiji.consolidated_class_dict)
for k in consolclass_weights:
    if consolclass_weights[k] == float("inf"):
        consolclass_weights[k] = 0
# Out:
# Mosaic Count:  1
# ./utils\loadcoraldata_utils.py:209: RuntimeWarning: divide by zero encountered in long_scalars
#   self.consolclass_weights = dict((k, (self.truthimage_consolidated.shape[0]*self.truthimage_consolidated.shape[1])/(self.truthimage_consolidated==newclassdict[k]).sum()) for k in newclassdict)
# Outputing Training...
# 14 of 24 total classes found and saved
#
#
# Outputing Validation...
# 14 of 24 total classes found and saved
# Mosaic Count:  2
# Outputing Training...
# 14 of 24 total classes found and saved
#
#
# Outputing Validation...
# 14 of 24 total classes found and saved
# Mosaic Count:  3
# Outputing Training...
# 14 of 24 total classes found and saved
#
#
# Outputing Validation...
# 14 of 24 total classes found and saved
# Mosaic Count:  4
# Outputing Training...
# 19 of 24 total classes found and saved
#
#
# Outputing Validation...
# 19 of 24 total classes found and saved
# Mosaic Count:  5
# Outputing Training...
# 19 of 24 total classes found and saved
#
#
# Outputing Validation...
# 19 of 24 total classes found and saved
# Mosaic Count:  6
# Outputing Training...
# 19 of 24 total classes found and saved
#
#
# Outputing Validation...
# 19 of 24 total classes found and saved
# Mosaic Count:  7
# Outputing Training...
# 19 of 24 total classes found and saved
#
#
# Outputing Validation...
# 19 of 24 total classes found and saved
# Mosaic Count:  8
# Outputing Training...
# 15 of 24 total classes found and saved
#
#
# Outputing Validation...
# 15 of 24 total classes found and saved
# Mosaic Count:  9
# Outputing Training...
# 15 of 24 total classes found and saved
#
#
# Outputing Validation...
# 15 of 24 total classes found and saved
# Mosaic Count:  10
# Outputing Training...
# 15 of 24 total classes found and saved
#
#
# Outputing Validation...
# 15 of 24 total classes found and saved
# Mosaic Count:  11
# Outputing Training...
# 15 of 24 total classes found and saved
#
#
# Outputing Validation...
# 15 of 24 total classes found and saved
# Mosaic Count:  12
# Outputing Training...
# 15 of 24 total classes found and saved
#
#
# Outputing Validation...
# 15 of 24 total classes found and saved
# Mosaic Count:  13
# Outputing Training...
# 15 of 24 total classes found and saved
#
#
# Outputing Validation...
# 15 of 24 total classes found and saved
# Mosaic Count:  14
# Outputing Training...
# 19 of 24 total classes found and saved
#
#
# Outputing Validation...
# 19 of 24 total classes found and saved
# Mosaic Count:  15
# Outputing Training...
# 21 of 24 total classes found and saved
#
#
# Outputing Validation...
# 21 of 24 total classes found and saved
# Mosaic Count:  16
# Outputing Training...
# 21 of 24 total classes found and saved
#
#
# Outputing Validation...
# 21 of 24 total classes found and saved
# Mosaic Count:  17
# Outputing Training...
# 21 of 24 total classes found and saved
#
#
# Outputing Validation...
# 21 of 24 total classes found and saved
# Mosaic Count:  18
# Outputing Training...
# 21 of 24 total classes found and saved
#
#
# Outputing Validation...
# 21 of 24 total classes found and saved
# Mosaic Count:  19
# Outputing Training...
# 20 of 24 total classes found and saved
#
#
# Outputing Validation...
# 20 of 24 total classes found and saved
# Mosaic Count:  20
# Outputing Training...
# 20 of 24 total classes found and saved
#
#
# Outputing Validation...
# 20 of 24 total classes found and saved
# Mosaic Count:  21
# Outputing Training...
# 20 of 24 total classes found and saved
#
#
# Outputing Validation...
# 20 of 24 total classes found and saved
# Mosaic Count:  22
# Outputing Training...
# 19 of 24 total classes found and saved
#
#
# Outputing Validation...
# 19 of 24 total classes found and saved
# Mosaic Count:  23
# Outputing Training...
# 18 of 24 total classes found and saved
#
#
# Outputing Validation...
# 18 of 24 total classes found and saved
# Mosaic Count:  24
# Outputing Training...
# 17 of 24 total classes found and saved
#
#
# Outputing Validation...
# 17 of 24 total classes found and saved
# Mosaic Count:  25
# Outputing Training...
# 18 of 24 total classes found and saved
#
#
# Outputing Validation...
# 18 of 24 total classes found and saved
# Mosaic Count:  26
# Outputing Training...
# 18 of 24 total classes found and saved
#
#
# Outputing Validation...
# 18 of 24 total classes found and saved
# Mosaic Count:  27
# Outputing Training...
# 18 of 24 total classes found and saved
#
#
# Outputing Validation...
# 18 of 24 total classes found and saved
# Mosaic Count:  28
# Outputing Training...
# 19 of 24 total classes found and saved
#
#
# Outputing Validation...
# 19 of 24 total classes found and saved
# Mosaic Count:  29
# Outputing Training...
# 19 of 24 total classes found and saved
#
#
# Outputing Validation...
# 19 of 24 total classes found and saved
# Mosaic Count:  30
# Outputing Training...
# 19 of 24 total classes found and saved
#
#
# Outputing Validation...
# 19 of 24 total classes found and saved
# Mosaic Count:  31
# Outputing Training...
# 19 of 24 total classes found and saved
#
#
# Outputing Validation...
# 19 of 24 total classes found and saved
# Mosaic Count:  32
# Outputing Training...
# 19 of 24 total classes found and saved
#
#
# Outputing Validation...
# 19 of 24 total classes found and saved
# Mosaic Count:  33
# Outputing Training...
# 18 of 24 total classes found and saved
#
#
# Outputing Validation...
# 18 of 24 total classes found and saved
# Mosaic Count:  34
# Outputing Training...
# 17 of 24 total classes found and saved
#
#
# Outputing Validation...
# 17 of 24 total classes found and saved
# Mosaic Count:  35
# Outputing Training...
# 20 of 24 total classes found and saved
#
#
# Outputing Validation...
# 20 of 24 total classes found and saved
# Mosaic Count:  36

# %%
with open("init_args - Fijitest.yml", 'r') as stream:
    try:
        init_args = yaml.load(stream)
    except yaml.YAMLError as exc:
        print(exc)
        
train_loader = ImageSetLoader(**init_args['image_set_loader']['train'])
val_loader = ImageSetLoader(**init_args['image_set_loader']['val'])
if train_loader.color_mode == 'rgb':
    num_channels = 3
elif train_loader.color_mode == '8channel':
    num_channels = 8
y = train_loader.target_size[1]
x = train_loader.target_size[0]

pixel_mean =250*np.ones(num_channels)
pixel_std = 250*np.ones(num_channels)
datagen = NeMOImageGenerator(image_shape = (y,x,num_channels),
    image_resample=True, pixelwise_center=True,
    pixel_mean=pixel_mean, pixelwise_std_normalization=True,
    pixel_std=pixel_std)

train_generator = datagen.flow_from_NeMOdirectory(output_trainpath,
    target_size=(y,x),
    color_mode=train_loader.color_mode,
    passedclasses = Fiji.consolidated_class_dict,
    class_mode = 'categorical',
    batch_size = 50,
    shuffle=True)
# Out:
# Found 3740 images belonging to 17 classes, split into 39 consolidated classes.
# class idx startend:  [[0, 220], [220, 440], [440, 660], [660, 880], [880, 1100], [1100, 1320], [1320, 1540], [1540, 1760], [1760, 1980], [1980, 2200], [2200, 2420], [2420, 2640], [2640, 2860], [2860, 3080], [3080, 3300], [3300, 3520], [3520, 3740]]

# %%
max_R = np.max(Testutils.image[:,:,4])
max_G = np.max(Testutils.image[:,:,2])
max_B = np.max(Testutils.image[:,:,1])
Testutils_RGB = np.rollaxis(np.asarray([1/max_R*Testutils.image[:,:,4], 1/max_G*Testutils.image[:,:,2], 1/max_B*Testutils.image[:,:,1]]),0,3)


plt.figure(1)
plt.imshow(Testutils.truthimage)
plt.show()

plt.figure(2)
plt.imshow(Testutils_RGB)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
print(np.unique(Fiji.truthimage))
print(np.unique(Fiji.truthimage_consolidated))
print(Fiji.consolidated_class_dict)
# Out:
# [ 1  2  4  5  6  7  8  9 10 23 27 28 29 30 33 36 39]
# [ 1  3  4  6  7  8 13 14 15 17 20 22 23 24]
# {'Reef Crest - coralline algae ridge': 1, 'Fore-reef deep slope': 2, 'Fore-reef shallow slope': 3, 'Fore-reef shallow terrace': 4, 'Fore-reef octocorals-dominated (Caribbean)': 5, 'Back-reef pavement': 6, 'Back-reef coral framework': 7, 'Back-reef coral bommies': 8, 'Back-reef octocorals-dominated (Caribbean)': 9, 'Lagoon Pinnacle reefs': 10, 'Lagoon Patch reefs': 11, 'Lagoon Fringing reefs': 12, 'Lagoon Deep water': 13, 'Fore-reef sand flats': 14, 'Back-reef sediment-dominated': 15, 'Lagoon sediment apron - Barren': 16, 'Terrestrial Vegetated': 17, 'Terrestrial Mangroves': 18, 'Intertidal Wetlands': 19, 'Beach (sand)': 20, 'Beach (rock)': 21, 'Seagrass Meadows': 22, 'Deep Ocean Water': 23, 'Other': 24}

# %%
plt.figure(3)
plt.imshow(Testutils.truthimage_consolidated)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="975">

# %%
jsonpath = './utils/CoralClasses.json'
with open(jsonpath) as json_file:
    json_data = json.load(json_file)
consolclass_count = dict((k, 0) for k in json_data["L3_ClassDict"])
    
mosaic_count = 1

imgpath = 'F:/Images//processed_Fiji_files/mosaiced_' + str(mosaic_count).zfill(3) + '.TIF'
truthpath = 'F:/Images//processed_Fiji_files/truth_classes_wcldMask_' + str(mosaic_count).zfill(3) + '.TIF'
output_trainpath = 'F:/Images/Fiji_Training_Patches_256/'
output_trainrefpath = 'F:/Images/Fiji_TrainingRef_Patches_256/'
output_trainfilename = 'rastertrain.txt'
output_validpath = 'F:/Images/Fiji_Valid_Patches_256/'
output_validrefpath = 'F:/Images/Fiji_ValidRef_Patches_256/'
output_validfilename = 'rastervalid.txt'

Fiji = coralutils.CoralData(imgpath, Truthpath=truthpath, truth_key=json_data["Fiji_ClassDict"], load_type="raster")
Fiji.Consolidate_classes(newclassdict=json_data["L3_ClassDict"], transferdict=json_data["Fiji2L3_Dict"])
anchormean, anchorstd, anchormin, anchormax = Fiji.get_anchors(classdict = json_data["L3_ClassDict"], 
                                            anchorlist = ['Terrestrial Vegetated', 'Deep Ocean Water'])
print(anchormean)
print(anchorstd)
print(anchormin)
print(anchormax)

mosaic_mean = np.mean(anchormean, axis=0)
#mosaic_std = np.max(np.asarray([np.abs(mosaic_mean-np.min(anchormin, axis=0)), 
#                                 np.abs(mosaic_mean-np.max(anchormax, axis=0))]), axis=0)
mosaic_std = 3*np.max(anchorstd, axis=0)

print(mosaic_mean)
print(mosaic_std)
#print(mosaic_std)
# Out:
# ./utils\loadcoraldata_utils.py:209: RuntimeWarning: divide by zero encountered in long_scalars
#   self.consolclass_weights = dict((k, (self.truthimage_consolidated.shape[0]*self.truthimage_consolidated.shape[1])/(self.truthimage_consolidated==newclassdict[k]).sum()) for k in newclassdict)
# [[70.33851038 62.39089616 51.28461611 37.93664539 28.54001356 68.57705979
#   98.3705201  64.83431537]
#  [78.57274003 68.05375553 37.84517468 24.7897111  18.2206438  12.68950575
#    8.36294837  5.08761512]]
# [[ 4.83974174  8.51970409 13.46604955 13.82674467 13.63633485 24.07441796
#   37.37691166 23.92296389]
#  [ 5.10123353  7.28614854  7.06057988  6.52004772  6.1119665   4.87956036
#    4.11007528  2.63110796]]
# [[62.29278564 48.0397377  26.37708282 16.28001404 10.19975853 11.03012371
#    9.03033066  6.02015162]
#  [65.42045593 51.42715454 26.99050331 16.09912491  9.94476414  6.58743477
#    3.11956882  1.80604553]]
# [[361.76730347 496.41061401 411.19622803 364.12963867 406.97033691
#   301.33685303 285.1942749  178.19648743]
#  [283.83615112 351.36755371 318.77420044 291.05044556 270.54858398
#   222.7472229  183.72618103 124.7375412 ]]
# [74.45562521 65.22232585 44.56489539 31.36317825 23.38032868 40.63328277
#  53.36673423 34.96096525]
# [ 15.30370058  25.55911226  40.39814866  41.48023402  40.90900454
#   72.22325387 112.13073499  71.76889167]

# %%
print(consolclass_weights)
# Out:
# {'Reef Crest - coralline algae ridge': 122.51391227369773, 'Fore-reef deep slope': 0, 'Fore-reef shallow slope': 115.12512946818141, 'Fore-reef shallow terrace': 108.58774298263833, 'Fore-reef octocorals-dominated (Caribbean)': 0, 'Back-reef pavement': 24.091198518651257, 'Back-reef coral framework': 1619.1200321156161, 'Back-reef coral bommies': 4608.650995755795, 'Back-reef octocorals-dominated (Caribbean)': 0, 'Lagoon Pinnacle reefs': 0, 'Lagoon Patch reefs': 0, 'Lagoon Fringing reefs': 0, 'Lagoon Deep water': 5923.750734368443, 'Fore-reef sand flats': 1152.7272578801242, 'Back-reef sediment-dominated': 109.00868745994116, 'Lagoon sediment apron - Barren': 0, 'Terrestrial Vegetated': 3.9729867372422634, 'Terrestrial Mangroves': 0, 'Intertidal Wetlands': 0, 'Beach (sand)': 422.03082350479093, 'Beach (rock)': 0, 'Seagrass Meadows': 76.70712960220835, 'Deep Ocean Water': 2.0189118100558163, 'Other': 6.290627915386691}
