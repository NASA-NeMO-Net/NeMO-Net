# %%
# %matplotlib notebook

import sys
import os
import numpy as np
import cv2
sys.path.append("./utils/") # Adds higher directory to python modules path.
import loadcoraldata_utils as coralutils
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
from matplotlib import colors
from NeMO_losses import charbonnierLoss
import NeMO_layers
from keras.models import Model, Sequential, load_model
from scipy.misc import imresize
from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean
from metrics import metrics
import json

import tensorflow as tf
from tensorflow.python.client import device_lib
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %matplotlib notebook

model = load_model('./tmp/Test_StyleTransfer.h5', custom_objects={'BilinearUpSampling2D':NeMO_layers.BilinearUpSampling2D, 'charbonnierLoss': charbonnierLoss, 'Var_Loss':NeMO_layers.Var_Loss, 'Gram_Loss':NeMO_layers.Gram_Loss, 'Content_Loss':NeMO_layers.Content_Loss})
# Out:
# Using TensorFlow backend.
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# WARNING:tensorflow:From /home/asli/NeMO-Test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1188: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/asli/NeMO-Test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1205: calling reduce_prod (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/asli/NeMO-Test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1290: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
model.summary()
Input = model.get_layer("model_1").get_input_at(0)
Style_layer = model.get_layer("model_1").get_output_at(0)

print("Cut Model:")
supermodel = Model(Input, Style_layer)
supermodel.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_3 (InputLayer)             (None, 256, 256, 4)   0
# ____________________________________________________________________________________________________
# input_2 (InputLayer)             (None, 256, 256, 4)   0
# ____________________________________________________________________________________________________
# model_1 (Model)                  (None, 256, 256, 4)   70203748    input_3[0][0]
# ____________________________________________________________________________________________________
# model_2 (Model)                  [(None, 64, 64, 128), 125632      input_2[0][0]
#                                                                    model_1[1][0]
# ____________________________________________________________________________________________________
# model_3 (Model)                  (None, 64, 64, 128)   180160      input_3[0][0]
#                                                                    model_1[1][0]
# ____________________________________________________________________________________________________
# gram__loss_1 (Gram_Loss)         (None, 1)             0           model_2[1][0]
#                                                                    model_2[2][0]
# ____________________________________________________________________________________________________
# gram__loss_2 (Gram_Loss)         (None, 1)             0           model_2[1][1]
#                                                                    model_2[2][1]
# ____________________________________________________________________________________________________
# content__loss_1 (Content_Loss)   (None, 1)             0           model_3[1][0]
#                                                                    model_3[2][0]
# ____________________________________________________________________________________________________
# add_48 (Add)                     (None, 1)             0           gram__loss_1[0][0]
#                                                                    gram__loss_2[0][0]
#                                                                    content__loss_1[0][0]
# ====================================================================================================
# Total params: 70,509,540
# Trainable params: 70,151,972
# Non-trainable params: 357,568
# ____________________________________________________________________________________________________
# Cut Model:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 256, 256, 4)   0
# ____________________________________________________________________________________________________
# vgg_convblock1_conv1 (Conv2D)    (None, 128, 128, 64)  12608       input_1[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock1_BatchNorm1 (Batch (None, 128, 128, 64)  256         vgg_convblock1_conv1[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock1_Activ1 (Activatio (None, 128, 128, 64)  0           vgg_convblock1_BatchNorm1[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock1_pool1 (MaxPooling (None, 64, 64, 64)    0           vgg_convblock1_Activ1[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock2_str1_par1_conv1 ( (None, 64, 64, 64)    4160        vgg_convblock1_pool1[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock2_str1_par1_BatchNo (None, 64, 64, 64)    256         vgg_convblock2_str1_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock2_str1_par1_Activ1  (None, 64, 64, 64)    0           vgg_convblock2_str1_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock2_str1_par1_conv2 ( (None, 64, 64, 64)    36928       vgg_convblock2_str1_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock2_str1_par1_BatchNo (None, 64, 64, 64)    256         vgg_convblock2_str1_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock2_str1_par1_Activ2  (None, 64, 64, 64)    0           vgg_convblock2_str1_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock2_str1_par1_conv3 ( (None, 64, 64, 128)   8320        vgg_convblock2_str1_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock2_str1_par2_conv1 ( (None, 64, 64, 128)   8320        vgg_convblock1_pool1[0][0]
# ____________________________________________________________________________________________________
# add_1 (Add)                      (None, 64, 64, 128)   0           vgg_convblock2_str1_par1_conv3[0]
#                                                                    vgg_convblock2_str1_par2_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock2_str2_par1_BatchNo (None, 64, 64, 128)   512         add_1[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock2_str2_par1_Activ1  (None, 64, 64, 128)   0           vgg_convblock2_str2_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock2_str2_par1_conv1 ( (None, 64, 64, 64)    8256        vgg_convblock2_str2_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock2_str2_par1_BatchNo (None, 64, 64, 64)    256         vgg_convblock2_str2_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock2_str2_par1_Activ2  (None, 64, 64, 64)    0           vgg_convblock2_str2_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock2_str2_par1_conv2 ( (None, 64, 64, 64)    36928       vgg_convblock2_str2_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock2_str2_par1_BatchNo (None, 64, 64, 64)    256         vgg_convblock2_str2_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock2_str2_par1_Activ3  (None, 64, 64, 64)    0           vgg_convblock2_str2_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock2_str2_par1_conv3 ( (None, 64, 64, 128)   8320        vgg_convblock2_str2_par1_Activ3[0
# ____________________________________________________________________________________________________
# add_2 (Add)                      (None, 64, 64, 128)   0           vgg_convblock2_str2_par1_conv3[0]
#                                                                    add_1[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock2_str3_par1_BatchNo (None, 64, 64, 128)   512         add_2[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock2_str3_par1_Activ1  (None, 64, 64, 128)   0           vgg_convblock2_str3_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock2_str3_par1_conv1 ( (None, 64, 64, 64)    8256        vgg_convblock2_str3_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock2_str3_par1_BatchNo (None, 64, 64, 64)    256         vgg_convblock2_str3_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock2_str3_par1_Activ2  (None, 64, 64, 64)    0           vgg_convblock2_str3_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock2_str3_par1_conv2 ( (None, 64, 64, 64)    36928       vgg_convblock2_str3_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock2_str3_par1_BatchNo (None, 64, 64, 64)    256         vgg_convblock2_str3_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock2_str3_par1_Activ3  (None, 64, 64, 64)    0           vgg_convblock2_str3_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock2_str3_par1_conv3 ( (None, 64, 64, 128)   8320        vgg_convblock2_str3_par1_Activ3[0
# ____________________________________________________________________________________________________
# add_3 (Add)                      (None, 64, 64, 128)   0           vgg_convblock2_str3_par1_conv3[0]
#                                                                    add_2[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str1_par1_BatchNo (None, 64, 64, 128)   512         add_3[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str1_par1_Activ1  (None, 64, 64, 128)   0           vgg_convblock3_str1_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock3_str1_par1_conv1 ( (None, 32, 32, 128)   16512       vgg_convblock3_str1_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock3_str1_par1_BatchNo (None, 32, 32, 128)   512         vgg_convblock3_str1_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str1_par1_Activ2  (None, 32, 32, 128)   0           vgg_convblock3_str1_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock3_str1_par1_conv2 ( (None, 32, 32, 128)   147584      vgg_convblock3_str1_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock3_str1_par1_BatchNo (None, 32, 32, 128)   512         vgg_convblock3_str1_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str1_par1_Activ3  (None, 32, 32, 128)   0           vgg_convblock3_str1_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock3_str1_par1_conv3 ( (None, 32, 32, 256)   33024       vgg_convblock3_str1_par1_Activ3[0
# ____________________________________________________________________________________________________
# vgg_convblock3_str1_par2_conv1 ( (None, 32, 32, 256)   33024       add_3[0][0]
# ____________________________________________________________________________________________________
# add_4 (Add)                      (None, 32, 32, 256)   0           vgg_convblock3_str1_par1_conv3[0]
#                                                                    vgg_convblock3_str1_par2_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str2_par1_BatchNo (None, 32, 32, 256)   1024        add_4[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str2_par1_Activ1  (None, 32, 32, 256)   0           vgg_convblock3_str2_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock3_str2_par1_conv1 ( (None, 32, 32, 128)   32896       vgg_convblock3_str2_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock3_str2_par1_BatchNo (None, 32, 32, 128)   512         vgg_convblock3_str2_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str2_par1_Activ2  (None, 32, 32, 128)   0           vgg_convblock3_str2_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock3_str2_par1_conv2 ( (None, 32, 32, 128)   147584      vgg_convblock3_str2_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock3_str2_par1_BatchNo (None, 32, 32, 128)   512         vgg_convblock3_str2_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str2_par1_Activ3  (None, 32, 32, 128)   0           vgg_convblock3_str2_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock3_str2_par1_conv3 ( (None, 32, 32, 256)   33024       vgg_convblock3_str2_par1_Activ3[0
# ____________________________________________________________________________________________________
# add_5 (Add)                      (None, 32, 32, 256)   0           vgg_convblock3_str2_par1_conv3[0]
#                                                                    add_4[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str3_par1_BatchNo (None, 32, 32, 256)   1024        add_5[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str3_par1_Activ1  (None, 32, 32, 256)   0           vgg_convblock3_str3_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock3_str3_par1_conv1 ( (None, 32, 32, 128)   32896       vgg_convblock3_str3_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock3_str3_par1_BatchNo (None, 32, 32, 128)   512         vgg_convblock3_str3_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str3_par1_Activ2  (None, 32, 32, 128)   0           vgg_convblock3_str3_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock3_str3_par1_conv2 ( (None, 32, 32, 128)   147584      vgg_convblock3_str3_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock3_str3_par1_BatchNo (None, 32, 32, 128)   512         vgg_convblock3_str3_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str3_par1_Activ3  (None, 32, 32, 128)   0           vgg_convblock3_str3_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock3_str3_par1_conv3 ( (None, 32, 32, 256)   33024       vgg_convblock3_str3_par1_Activ3[0
# ____________________________________________________________________________________________________
# add_6 (Add)                      (None, 32, 32, 256)   0           vgg_convblock3_str3_par1_conv3[0]
#                                                                    add_5[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str4_par1_BatchNo (None, 32, 32, 256)   1024        add_6[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str4_par1_Activ1  (None, 32, 32, 256)   0           vgg_convblock3_str4_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock3_str4_par1_conv1 ( (None, 32, 32, 128)   32896       vgg_convblock3_str4_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock3_str4_par1_BatchNo (None, 32, 32, 128)   512         vgg_convblock3_str4_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str4_par1_Activ2  (None, 32, 32, 128)   0           vgg_convblock3_str4_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock3_str4_par1_conv2 ( (None, 32, 32, 128)   147584      vgg_convblock3_str4_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock3_str4_par1_BatchNo (None, 32, 32, 128)   512         vgg_convblock3_str4_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock3_str4_par1_Activ3  (None, 32, 32, 128)   0           vgg_convblock3_str4_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock3_str4_par1_conv3 ( (None, 32, 32, 256)   33024       vgg_convblock3_str4_par1_Activ3[0
# ____________________________________________________________________________________________________
# add_7 (Add)                      (None, 32, 32, 256)   0           vgg_convblock3_str4_par1_conv3[0]
#                                                                    add_6[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str1_par1_BatchNo (None, 32, 32, 256)   1024        add_7[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str1_par1_Activ1  (None, 32, 32, 256)   0           vgg_convblock4_str1_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str1_par1_conv1 ( (None, 16, 16, 256)   65792       vgg_convblock4_str1_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock4_str1_par1_BatchNo (None, 16, 16, 256)   1024        vgg_convblock4_str1_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str1_par1_Activ2  (None, 16, 16, 256)   0           vgg_convblock4_str1_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str1_par1_conv2 ( (None, 16, 16, 256)   590080      vgg_convblock4_str1_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock4_str1_par1_BatchNo (None, 16, 16, 256)   1024        vgg_convblock4_str1_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str1_par1_Activ3  (None, 16, 16, 256)   0           vgg_convblock4_str1_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str1_par1_conv3 ( (None, 16, 16, 512)   131584      vgg_convblock4_str1_par1_Activ3[0
# ____________________________________________________________________________________________________
# vgg_convblock4_str1_par2_conv1 ( (None, 16, 16, 512)   131584      add_7[0][0]
# ____________________________________________________________________________________________________
# add_8 (Add)                      (None, 16, 16, 512)   0           vgg_convblock4_str1_par1_conv3[0]
#                                                                    vgg_convblock4_str1_par2_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str2_par1_BatchNo (None, 16, 16, 512)   2048        add_8[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str2_par1_Activ1  (None, 16, 16, 512)   0           vgg_convblock4_str2_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str2_par1_conv1 ( (None, 16, 16, 256)   131328      vgg_convblock4_str2_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock4_str2_par1_BatchNo (None, 16, 16, 256)   1024        vgg_convblock4_str2_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str2_par1_Activ2  (None, 16, 16, 256)   0           vgg_convblock4_str2_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str2_par1_conv2 ( (None, 16, 16, 256)   590080      vgg_convblock4_str2_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock4_str2_par1_BatchNo (None, 16, 16, 256)   1024        vgg_convblock4_str2_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str2_par1_Activ3  (None, 16, 16, 256)   0           vgg_convblock4_str2_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str2_par1_conv3 ( (None, 16, 16, 512)   131584      vgg_convblock4_str2_par1_Activ3[0
# ____________________________________________________________________________________________________
# add_9 (Add)                      (None, 16, 16, 512)   0           vgg_convblock4_str2_par1_conv3[0]
#                                                                    add_8[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str3_par1_BatchNo (None, 16, 16, 512)   2048        add_9[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str3_par1_Activ1  (None, 16, 16, 512)   0           vgg_convblock4_str3_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str3_par1_conv1 ( (None, 16, 16, 256)   131328      vgg_convblock4_str3_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock4_str3_par1_BatchNo (None, 16, 16, 256)   1024        vgg_convblock4_str3_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str3_par1_Activ2  (None, 16, 16, 256)   0           vgg_convblock4_str3_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str3_par1_conv2 ( (None, 16, 16, 256)   590080      vgg_convblock4_str3_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock4_str3_par1_BatchNo (None, 16, 16, 256)   1024        vgg_convblock4_str3_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str3_par1_Activ3  (None, 16, 16, 256)   0           vgg_convblock4_str3_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str3_par1_conv3 ( (None, 16, 16, 512)   131584      vgg_convblock4_str3_par1_Activ3[0
# ____________________________________________________________________________________________________
# add_10 (Add)                     (None, 16, 16, 512)   0           vgg_convblock4_str3_par1_conv3[0]
#                                                                    add_9[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str4_par1_BatchNo (None, 16, 16, 512)   2048        add_10[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str4_par1_Activ1  (None, 16, 16, 512)   0           vgg_convblock4_str4_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str4_par1_conv1 ( (None, 16, 16, 256)   131328      vgg_convblock4_str4_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock4_str4_par1_BatchNo (None, 16, 16, 256)   1024        vgg_convblock4_str4_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str4_par1_Activ2  (None, 16, 16, 256)   0           vgg_convblock4_str4_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str4_par1_conv2 ( (None, 16, 16, 256)   590080      vgg_convblock4_str4_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock4_str4_par1_BatchNo (None, 16, 16, 256)   1024        vgg_convblock4_str4_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str4_par1_Activ3  (None, 16, 16, 256)   0           vgg_convblock4_str4_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str4_par1_conv3 ( (None, 16, 16, 512)   131584      vgg_convblock4_str4_par1_Activ3[0
# ____________________________________________________________________________________________________
# add_11 (Add)                     (None, 16, 16, 512)   0           vgg_convblock4_str4_par1_conv3[0]
#                                                                    add_10[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str5_par1_BatchNo (None, 16, 16, 512)   2048        add_11[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str5_par1_Activ1  (None, 16, 16, 512)   0           vgg_convblock4_str5_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str5_par1_conv1 ( (None, 16, 16, 256)   131328      vgg_convblock4_str5_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock4_str5_par1_BatchNo (None, 16, 16, 256)   1024        vgg_convblock4_str5_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str5_par1_Activ2  (None, 16, 16, 256)   0           vgg_convblock4_str5_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str5_par1_conv2 ( (None, 16, 16, 256)   590080      vgg_convblock4_str5_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock4_str5_par1_BatchNo (None, 16, 16, 256)   1024        vgg_convblock4_str5_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str5_par1_Activ3  (None, 16, 16, 256)   0           vgg_convblock4_str5_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str5_par1_conv3 ( (None, 16, 16, 512)   131584      vgg_convblock4_str5_par1_Activ3[0
# ____________________________________________________________________________________________________
# add_12 (Add)                     (None, 16, 16, 512)   0           vgg_convblock4_str5_par1_conv3[0]
#                                                                    add_11[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str6_par1_BatchNo (None, 16, 16, 512)   2048        add_12[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str6_par1_Activ1  (None, 16, 16, 512)   0           vgg_convblock4_str6_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str6_par1_conv1 ( (None, 16, 16, 256)   131328      vgg_convblock4_str6_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock4_str6_par1_BatchNo (None, 16, 16, 256)   1024        vgg_convblock4_str6_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str6_par1_Activ2  (None, 16, 16, 256)   0           vgg_convblock4_str6_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str6_par1_conv2 ( (None, 16, 16, 256)   590080      vgg_convblock4_str6_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock4_str6_par1_BatchNo (None, 16, 16, 256)   1024        vgg_convblock4_str6_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock4_str6_par1_Activ3  (None, 16, 16, 256)   0           vgg_convblock4_str6_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock4_str6_par1_conv3 ( (None, 16, 16, 512)   131584      vgg_convblock4_str6_par1_Activ3[0
# ____________________________________________________________________________________________________
# add_13 (Add)                     (None, 16, 16, 512)   0           vgg_convblock4_str6_par1_conv3[0]
#                                                                    add_12[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock5_str1_par1_BatchNo (None, 16, 16, 512)   2048        add_13[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock5_str1_par1_Activ1  (None, 16, 16, 512)   0           vgg_convblock5_str1_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock5_str1_par1_conv1 ( (None, 8, 8, 512)     262656      vgg_convblock5_str1_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock5_str1_par1_BatchNo (None, 8, 8, 512)     2048        vgg_convblock5_str1_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock5_str1_par1_Activ2  (None, 8, 8, 512)     0           vgg_convblock5_str1_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock5_str1_par1_conv2 ( (None, 8, 8, 512)     2359808     vgg_convblock5_str1_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock5_str1_par1_BatchNo (None, 8, 8, 512)     2048        vgg_convblock5_str1_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock5_str1_par1_Activ3  (None, 8, 8, 512)     0           vgg_convblock5_str1_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock5_str1_par1_conv3 ( (None, 8, 8, 1024)    525312      vgg_convblock5_str1_par1_Activ3[0
# ____________________________________________________________________________________________________
# vgg_convblock5_str1_par2_conv1 ( (None, 8, 8, 1024)    525312      add_13[0][0]
# ____________________________________________________________________________________________________
# add_14 (Add)                     (None, 8, 8, 1024)    0           vgg_convblock5_str1_par1_conv3[0]
#                                                                    vgg_convblock5_str1_par2_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock5_str2_par1_BatchNo (None, 8, 8, 1024)    4096        add_14[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock5_str2_par1_Activ1  (None, 8, 8, 1024)    0           vgg_convblock5_str2_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock5_str2_par1_conv1 ( (None, 8, 8, 512)     524800      vgg_convblock5_str2_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock5_str2_par1_BatchNo (None, 8, 8, 512)     2048        vgg_convblock5_str2_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock5_str2_par1_Activ2  (None, 8, 8, 512)     0           vgg_convblock5_str2_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock5_str2_par1_conv2 ( (None, 8, 8, 512)     2359808     vgg_convblock5_str2_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock5_str2_par1_BatchNo (None, 8, 8, 512)     2048        vgg_convblock5_str2_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock5_str2_par1_Activ3  (None, 8, 8, 512)     0           vgg_convblock5_str2_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock5_str2_par1_conv3 ( (None, 8, 8, 1024)    525312      vgg_convblock5_str2_par1_Activ3[0
# ____________________________________________________________________________________________________
# add_15 (Add)                     (None, 8, 8, 1024)    0           vgg_convblock5_str2_par1_conv3[0]
#                                                                    add_14[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock5_str3_par1_BatchNo (None, 8, 8, 1024)    4096        add_15[0][0]
# ____________________________________________________________________________________________________
# vgg_convblock5_str3_par1_Activ1  (None, 8, 8, 1024)    0           vgg_convblock5_str3_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock5_str3_par1_conv1 ( (None, 8, 8, 512)     524800      vgg_convblock5_str3_par1_Activ1[0
# ____________________________________________________________________________________________________
# vgg_convblock5_str3_par1_BatchNo (None, 8, 8, 512)     2048        vgg_convblock5_str3_par1_conv1[0]
# ____________________________________________________________________________________________________
# vgg_convblock5_str3_par1_Activ2  (None, 8, 8, 512)     0           vgg_convblock5_str3_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock5_str3_par1_conv2 ( (None, 8, 8, 512)     2359808     vgg_convblock5_str3_par1_Activ2[0
# ____________________________________________________________________________________________________
# vgg_convblock5_str3_par1_BatchNo (None, 8, 8, 512)     2048        vgg_convblock5_str3_par1_conv2[0]
# ____________________________________________________________________________________________________
# vgg_convblock5_str3_par1_Activ3  (None, 8, 8, 512)     0           vgg_convblock5_str3_par1_BatchNor
# ____________________________________________________________________________________________________
# vgg_convblock5_str3_par1_conv3 ( (None, 8, 8, 1024)    525312      vgg_convblock5_str3_par1_Activ3[0
# ____________________________________________________________________________________________________
# add_16 (Add)                     (None, 8, 8, 1024)    0           vgg_convblock5_str3_par1_conv3[0]
#                                                                    add_15[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock1_bridgeconv1_str (None, 8, 8, 1024)    4096        add_16[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock1_bridgeconv1_str (None, 8, 8, 1024)    0           vgg_deconvblock1_bridgeconv1_str1
# ____________________________________________________________________________________________________
# vgg_deconvblock1_bridgeconv1_str (None, 8, 8, 1024)    9438208     vgg_deconvblock1_bridgeconv1_str1
# ____________________________________________________________________________________________________
# vgg_deconvblock1_bridgeconv1_str (None, 8, 8, 1024)    4096        vgg_deconvblock1_bridgeconv1_str1
# ____________________________________________________________________________________________________
# vgg_deconvblock1_bridgeconv1_str (None, 8, 8, 1024)    0           vgg_deconvblock1_bridgeconv1_str1
# ____________________________________________________________________________________________________
# vgg_deconvblock1_bridgeconv1_str (None, 8, 8, 1024)    9438208     vgg_deconvblock1_bridgeconv1_str1
# ____________________________________________________________________________________________________
# add_17 (Add)                     (None, 8, 8, 1024)    0           vgg_deconvblock1_bridgeconv1_str1
#                                                                    add_16[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock1_bridgeconv1_str (None, 8, 8, 1024)    4096        add_17[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock1_bridgeconv1_str (None, 8, 8, 1024)    0           vgg_deconvblock1_bridgeconv1_str2
# ____________________________________________________________________________________________________
# vgg_deconvblock1_bridgeconv1_str (None, 8, 8, 1024)    9438208     vgg_deconvblock1_bridgeconv1_str2
# ____________________________________________________________________________________________________
# vgg_deconvblock1_bridgeconv1_str (None, 8, 8, 1024)    4096        vgg_deconvblock1_bridgeconv1_str2
# ____________________________________________________________________________________________________
# vgg_deconvblock1_bridgeconv1_str (None, 8, 8, 1024)    0           vgg_deconvblock1_bridgeconv1_str2
# ____________________________________________________________________________________________________
# vgg_deconvblock1_bridgeconv1_str (None, 8, 8, 1024)    9438208     vgg_deconvblock1_bridgeconv1_str2
# ____________________________________________________________________________________________________
# add_18 (Add)                     (None, 8, 8, 1024)    0           vgg_deconvblock1_bridgeconv1_str2
#                                                                    add_17[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock1_bridgeconv1_str (None, 8, 8, 1024)    4096        add_18[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock1_bridgeconv1_str (None, 8, 8, 128)     1179776     vgg_deconvblock1_bridgeconv1_str3
# ____________________________________________________________________________________________________
# vgg_deconvblock1_nextconv1_str1_ (None, 8, 8, 128)     0           vgg_deconvblock1_bridgeconv1_str3
# ____________________________________________________________________________________________________
# vgg_deconvblock1_nextconv1_str2_ (None, 8, 8, 128)     0           vgg_deconvblock1_nextconv1_str1_A
# ____________________________________________________________________________________________________
# vgg_deconvblock1_nextconv1_str2_ (None, 8, 8, 128)     512         vgg_deconvblock1_nextconv1_str2_p
# ____________________________________________________________________________________________________
# vgg_deconvblock1_nextconv1_str2_ (None, 8, 8, 128)     147584      vgg_deconvblock1_nextconv1_str2_p
# ____________________________________________________________________________________________________
# add_19 (Add)                     (None, 8, 8, 128)     0           vgg_deconvblock1_nextconv1_str2_p
#                                                                    vgg_deconvblock1_nextconv1_str1_A
# ____________________________________________________________________________________________________
# vgg_deconvblock1_nextconv1_str2_ (None, 8, 8, 128)     0           add_19[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock1_nextconv1_str2_ (None, 8, 8, 128)     512         vgg_deconvblock1_nextconv1_str2_p
# ____________________________________________________________________________________________________
# vgg_deconvblock1_nextconv1_str2_ (None, 8, 8, 128)     147584      vgg_deconvblock1_nextconv1_str2_p
# ____________________________________________________________________________________________________
# add_20 (Add)                     (None, 8, 8, 128)     0           vgg_deconvblock1_nextconv1_str2_p
#                                                                    vgg_deconvblock1_nextconv1_str1_A
# ____________________________________________________________________________________________________
# vgg_deconvblock1_nextconv1_str3_ (None, 8, 8, 128)     512         add_20[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock1_nextconv1_str3_ (None, 8, 8, 128)     0           vgg_deconvblock1_nextconv1_str3_p
# ____________________________________________________________________________________________________
# vgg_deconvblock1_nextconv1_str3_ (None, 8, 8, 128)     147584      vgg_deconvblock1_nextconv1_str3_p
# ____________________________________________________________________________________________________
# vgg_deconvblock1_nextconv1_str3_ (None, 8, 8, 128)     512         vgg_deconvblock1_nextconv1_str3_p
# ____________________________________________________________________________________________________
# vgg_deconvblock1_nextconv1_str3_ (None, 8, 8, 128)     0           vgg_deconvblock1_nextconv1_str3_p
# ____________________________________________________________________________________________________
# vgg_deconvblock1_nextconv1_str3_ (None, 8, 8, 128)     147584      vgg_deconvblock1_nextconv1_str3_p
# ____________________________________________________________________________________________________
# add_21 (Add)                     (None, 8, 8, 128)     0           vgg_deconvblock1_nextconv1_str3_p
#                                                                    add_20[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock2_prevconv2_str1_ (None, 8, 8, 128)     512         add_21[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock2_bridgeconv2_str (None, 16, 16, 512)   2048        add_13[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock2_prevconv2_str1_ (None, 8, 8, 128)     0           vgg_deconvblock2_prevconv2_str1_p
# ____________________________________________________________________________________________________
# vgg_deconvblock2_bridgeconv2_str (None, 16, 16, 512)   0           vgg_deconvblock2_bridgeconv2_str1
# ____________________________________________________________________________________________________
# vgg_deconvblock2_prevconv2_str1_ (None, 8, 8, 128)     147584      vgg_deconvblock2_prevconv2_str1_p
# ____________________________________________________________________________________________________
# vgg_deconvblock2_bridgeconv2_str (None, 16, 16, 512)   2359808     vgg_deconvblock2_bridgeconv2_str1
# ____________________________________________________________________________________________________
# vgg_deconvblock2_prevconv2_str1_ (None, 8, 8, 128)     512         vgg_deconvblock2_prevconv2_str1_p
# ____________________________________________________________________________________________________
# vgg_deconvblock2_bridgeconv2_str (None, 16, 16, 512)   2048        vgg_deconvblock2_bridgeconv2_str1
# ____________________________________________________________________________________________________
# vgg_deconvblock2_prevconv2_str1_ (None, 8, 8, 128)     0           vgg_deconvblock2_prevconv2_str1_p
# ____________________________________________________________________________________________________
# vgg_deconvblock2_bridgeconv2_str (None, 16, 16, 512)   0           vgg_deconvblock2_bridgeconv2_str1
# ____________________________________________________________________________________________________
# vgg_deconvblock2_prevconv2_str1_ (None, 8, 8, 128)     147584      vgg_deconvblock2_prevconv2_str1_p
# ____________________________________________________________________________________________________
# vgg_deconvblock2_bridgeconv2_str (None, 16, 16, 512)   2359808     vgg_deconvblock2_bridgeconv2_str1
# ...
# ____________________________________________________________________________________________________
# vgg_deconvblock3_nextconv3_str3_ (None, 32, 32, 32)    128         vgg_deconvblock3_nextconv3_str3_p
# ____________________________________________________________________________________________________
# vgg_deconvblock3_nextconv3_str3_ (None, 32, 32, 32)    0           vgg_deconvblock3_nextconv3_str3_p
# ____________________________________________________________________________________________________
# vgg_deconvblock3_nextconv3_str3_ (None, 32, 32, 32)    9248        vgg_deconvblock3_nextconv3_str3_p
# ____________________________________________________________________________________________________
# add_37 (Add)                     (None, 32, 32, 32)    0           vgg_deconvblock3_nextconv3_str3_p
#                                                                    add_36[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_prevconv4_str1_ (None, 32, 32, 32)    128         add_37[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_bridgeconv4_str (None, 64, 64, 128)   512         add_3[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_prevconv4_str1_ (None, 32, 32, 32)    0           vgg_deconvblock4_prevconv4_str1_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_bridgeconv4_str (None, 64, 64, 128)   0           vgg_deconvblock4_bridgeconv4_str1
# ____________________________________________________________________________________________________
# vgg_deconvblock4_prevconv4_str1_ (None, 32, 32, 32)    9248        vgg_deconvblock4_prevconv4_str1_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_bridgeconv4_str (None, 64, 64, 128)   147584      vgg_deconvblock4_bridgeconv4_str1
# ____________________________________________________________________________________________________
# vgg_deconvblock4_prevconv4_str1_ (None, 32, 32, 32)    128         vgg_deconvblock4_prevconv4_str1_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_bridgeconv4_str (None, 64, 64, 128)   512         vgg_deconvblock4_bridgeconv4_str1
# ____________________________________________________________________________________________________
# vgg_deconvblock4_prevconv4_str1_ (None, 32, 32, 32)    0           vgg_deconvblock4_prevconv4_str1_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_bridgeconv4_str (None, 64, 64, 128)   0           vgg_deconvblock4_bridgeconv4_str1
# ____________________________________________________________________________________________________
# vgg_deconvblock4_prevconv4_str1_ (None, 32, 32, 32)    9248        vgg_deconvblock4_prevconv4_str1_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_bridgeconv4_str (None, 64, 64, 128)   147584      vgg_deconvblock4_bridgeconv4_str1
# ____________________________________________________________________________________________________
# add_40 (Add)                     (None, 32, 32, 32)    0           vgg_deconvblock4_prevconv4_str1_p
#                                                                    add_37[0][0]
# ____________________________________________________________________________________________________
# add_38 (Add)                     (None, 64, 64, 128)   0           vgg_deconvblock4_bridgeconv4_str1
#                                                                    add_3[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_prevconv4_str2_ (None, 32, 32, 32)    128         add_40[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_bridgeconv4_str (None, 64, 64, 128)   512         add_38[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_prevconv4_str2_ (None, 32, 32, 32)    0           vgg_deconvblock4_prevconv4_str2_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_bridgeconv4_str (None, 64, 64, 128)   0           vgg_deconvblock4_bridgeconv4_str2
# ____________________________________________________________________________________________________
# vgg_deconvblock4_prevconv4_str2_ (None, 32, 32, 32)    9248        vgg_deconvblock4_prevconv4_str2_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_bridgeconv4_str (None, 64, 64, 128)   147584      vgg_deconvblock4_bridgeconv4_str2
# ____________________________________________________________________________________________________
# vgg_deconvblock4_prevconv4_str2_ (None, 32, 32, 32)    128         vgg_deconvblock4_prevconv4_str2_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_bridgeconv4_str (None, 64, 64, 128)   512         vgg_deconvblock4_bridgeconv4_str2
# ____________________________________________________________________________________________________
# vgg_deconvblock4_prevconv4_str2_ (None, 32, 32, 32)    0           vgg_deconvblock4_prevconv4_str2_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_bridgeconv4_str (None, 64, 64, 128)   0           vgg_deconvblock4_bridgeconv4_str2
# ____________________________________________________________________________________________________
# vgg_deconvblock4_prevconv4_str2_ (None, 32, 32, 32)    9248        vgg_deconvblock4_prevconv4_str2_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_bridgeconv4_str (None, 64, 64, 128)   147584      vgg_deconvblock4_bridgeconv4_str2
# ____________________________________________________________________________________________________
# add_41 (Add)                     (None, 32, 32, 32)    0           vgg_deconvblock4_prevconv4_str2_p
#                                                                    add_40[0][0]
# ____________________________________________________________________________________________________
# add_39 (Add)                     (None, 64, 64, 128)   0           vgg_deconvblock4_bridgeconv4_str2
#                                                                    add_38[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_prevconv4_str3_ (None, 32, 32, 32)    128         add_41[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_bridgeconv4_str (None, 64, 64, 128)   512         add_39[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_prevconv4_str3_ (None, 32, 32, 16)    4624        vgg_deconvblock4_prevconv4_str3_B
# ____________________________________________________________________________________________________
# vgg_deconvblock4_bridgeconv4_str (None, 64, 64, 16)    18448       vgg_deconvblock4_bridgeconv4_str3
# ____________________________________________________________________________________________________
# vgg_deconvblock4_prevconv4_str3_ (None, 64, 64, 16)    0           vgg_deconvblock4_prevconv4_str3_c
# ____________________________________________________________________________________________________
# vgg_deconvblock4_scale (Lambda)  (None, 64, 64, 16)    0           vgg_deconvblock4_bridgeconv4_str3
# ____________________________________________________________________________________________________
# add_42 (Add)                     (None, 64, 64, 16)    0           vgg_deconvblock4_prevconv4_str3_B
#                                                                    vgg_deconvblock4_scale[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str1_ (None, 64, 64, 16)    0           add_42[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str2_ (None, 64, 64, 16)    0           vgg_deconvblock4_nextconv4_str1_A
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str2_ (None, 64, 64, 16)    64          vgg_deconvblock4_nextconv4_str2_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str2_ (None, 64, 64, 16)    2320        vgg_deconvblock4_nextconv4_str2_p
# ____________________________________________________________________________________________________
# add_43 (Add)                     (None, 64, 64, 16)    0           vgg_deconvblock4_nextconv4_str2_p
#                                                                    vgg_deconvblock4_nextconv4_str1_A
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str2_ (None, 64, 64, 16)    0           add_43[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str2_ (None, 64, 64, 16)    64          vgg_deconvblock4_nextconv4_str2_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str2_ (None, 64, 64, 16)    2320        vgg_deconvblock4_nextconv4_str2_p
# ____________________________________________________________________________________________________
# add_44 (Add)                     (None, 64, 64, 16)    0           vgg_deconvblock4_nextconv4_str2_p
#                                                                    vgg_deconvblock4_nextconv4_str1_A
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str3_ (None, 64, 64, 16)    64          add_44[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str3_ (None, 64, 64, 16)    0           vgg_deconvblock4_nextconv4_str3_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str3_ (None, 64, 64, 16)    2320        vgg_deconvblock4_nextconv4_str3_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str3_ (None, 64, 64, 16)    64          vgg_deconvblock4_nextconv4_str3_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str3_ (None, 64, 64, 16)    0           vgg_deconvblock4_nextconv4_str3_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str3_ (None, 64, 64, 16)    2320        vgg_deconvblock4_nextconv4_str3_p
# ____________________________________________________________________________________________________
# add_45 (Add)                     (None, 64, 64, 16)    0           vgg_deconvblock4_nextconv4_str3_p
#                                                                    add_44[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str4_ (None, 64, 64, 16)    64          add_45[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str4_ (None, 64, 64, 16)    0           vgg_deconvblock4_nextconv4_str4_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str4_ (None, 64, 64, 16)    2320        vgg_deconvblock4_nextconv4_str4_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str4_ (None, 64, 64, 16)    64          vgg_deconvblock4_nextconv4_str4_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str4_ (None, 64, 64, 16)    0           vgg_deconvblock4_nextconv4_str4_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str4_ (None, 64, 64, 16)    2320        vgg_deconvblock4_nextconv4_str4_p
# ____________________________________________________________________________________________________
# add_46 (Add)                     (None, 64, 64, 16)    0           vgg_deconvblock4_nextconv4_str4_p
#                                                                    add_45[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str5_ (None, 128, 128, 16)  0           add_46[0][0]
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str6_ (None, 128, 128, 16)  64          vgg_deconvblock4_nextconv4_str5_B
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str6_ (None, 128, 128, 16)  0           vgg_deconvblock4_nextconv4_str6_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str6_ (None, 128, 128, 16)  2320        vgg_deconvblock4_nextconv4_str6_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str6_ (None, 128, 128, 16)  64          vgg_deconvblock4_nextconv4_str6_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str6_ (None, 128, 128, 16)  0           vgg_deconvblock4_nextconv4_str6_p
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str6_ (None, 128, 128, 16)  2320        vgg_deconvblock4_nextconv4_str6_p
# ____________________________________________________________________________________________________
# add_47 (Add)                     (None, 128, 128, 16)  0           vgg_deconvblock4_nextconv4_str6_p
#                                                                    vgg_deconvblock4_nextconv4_str5_B
# ____________________________________________________________________________________________________
# vgg_deconvblock4_nextconv4_str7_ (None, 256, 256, 16)  0           add_47[0][0]
# ____________________________________________________________________________________________________
# final_1b1conv (Conv2D)           (None, 256, 256, 4)   68          vgg_deconvblock4_nextconv4_str7_B
# ====================================================================================================
# Total params: 70,203,748
# Trainable params: 70,151,972
# Non-trainable params: 51,776
# ____________________________________________________________________________________________________

# %%
# imgpath = '/home/asli/NeMO-Test/NeMO-NET/Images/CiciaDANN_Target_256/Coral/Coral_00000020.tif'
imgpath = '/home/asli/NeMO-Test/NeMO-NET/Images/Jarrett_Training_Patches/Coral/Coral_00000020.tif'
# truthpath = '/home/asli/NeMO-Test/NeMO-NET/Images/CiciaDANN_TargetRef_256/Coral_00000010.png'

jsonpath = './utils/CoralClasses.json'

with open(jsonpath) as json_file:
    json_data = json.load(json_file)

TestImg = coralutils.CoralData(imgpath,load_type="raster")
TestImg.testimage = TestImg.image[:,:,:]
TestImg.testimage = np.delete(TestImg.testimage, [0,3,5,7], 2) # harded coded for BGR + NIR

imgbatch = np.expand_dims(TestImg.testimage, axis=0)
imgpredict = supermodel.predict(imgbatch, batch_size = 1)[0]

fig = plt.figure(1,figsize=(12,12))
ax = plt.subplot(1,2,1)
patch_R = 100*TestImg.testimage[:,:,2]+100
patch_G = 100*TestImg.testimage[:,:,1]+100
patch_B = 100*TestImg.testimage[:,:,0]+100
patch_R[patch_R > 255] = 255
patch_G[patch_G > 255] = 255
patch_B[patch_B > 255] = 255
ax = plt.subplot(121)
ax.imshow(np.rollaxis(np.asarray([patch_R, patch_G, patch_B], dtype=np.uint8),0,3))


patch_R = 100*imgpredict[:,:,2]+100
patch_G = 100*imgpredict[:,:,1]+100
patch_B = 100*imgpredict[:,:,0]+100
patch_R[patch_R > 255] = 255
patch_G[patch_G > 255] = 255
patch_B[patch_B > 255] = 255
ax = plt.subplot(122)
ax.imshow(np.rollaxis(np.asarray([patch_R, patch_G, patch_B], dtype=np.uint8),0,3))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-45c40317cee5> in <module>()
#       8     json_data = json.load(json_file)
#       9
# ---> 10 TestImg = coralutils.CoralData(imgpath,load_type="raster")
#      11 TestImg.testimage = TestImg.image[:,:,:]
#      12 TestImg.testimage = np.delete(TestImg.testimage, [0,3,5,7], 2) # harded coded for BGR + NIR
#
# ~/NeMO-Test/NeMO-NET/CNN/utils/loadcoraldata_utils.py in __init__(self, Imagepath, Truthpath, Testpath, Bathypath, truth_key, load_type, tfwpath)
#      59                         except Exception:
#      60                                 pass
# ---> 61                         xsize = img.RasterXSize
#      62                         ysize = img.RasterYSize
#      63
#
# AttributeError: 'NoneType' object has no attribute 'RasterXSize'
